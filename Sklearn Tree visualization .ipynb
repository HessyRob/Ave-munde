# %%
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree, export_text

# %%
#using a diabetes for example
import pandas as pd
df = pd.read_csv('diabetes.csv')
# setting the X , y 
X=df.drop(columns=['Outcome'])
y=df['Outcome']

# %%
features=list(df.columns[0:-1])
class_name=["non_diabetic", "diabetic"]

# %%
dt = DecisionTreeClassifier(max_depth=3, random_state=3)

# %%
dt.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=3, splitter='best')

# %%
plt.figure(figsize=(15,15))
plot_tree(dt, feature_names=features, filled =True, class_names=class_name);

# %%
print(export_text(dt, feature_names=features, show_weights=True))
# Out:
# |--- Glucose <= 127.50
# |   |--- Age <= 28.50
# |   |   |--- BMI <= 45.40
# |   |   |   |--- weights: [247.00, 20.00] class: 0
# |   |   |--- BMI >  45.40
# |   |   |   |--- weights: [1.00, 3.00] class: 1
# |   |--- Age >  28.50
# |   |   |--- BMI <= 26.35
# |   |   |   |--- weights: [39.00, 2.00] class: 0
# |   |   |--- BMI >  26.35
# |   |   |   |--- weights: [104.00, 69.00] class: 0
# |--- Glucose >  127.50
# |   |--- BMI <= 29.95
# |   |   |--- Glucose <= 145.50
# |   |   |   |--- weights: [35.00, 6.00] class: 0
# |   |   |--- Glucose >  145.50
# |   |   |   |--- weights: [17.00, 18.00] class: 1
# |   |--- BMI >  29.95
# |   |   |--- Glucose <= 157.50
# |   |   |   |--- weights: [45.00, 70.00] class: 1
# |   |   |--- Glucose >  157.50
# |   |   |   |--- weights: [12.00, 80.00] class: 1
